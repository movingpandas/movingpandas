# %% [markdown]
# # Getting started with MovingPanda
#
# MovingPandas provides a trajectory datatype based on GeoPandas
#
# https://github.com/anitagraser/movingpandas

# %%
# %matplotlib inline

# %%
import urllib
import os
import pandas as pd
import movingpandas as mp
import contextily as ctx
from geopandas import GeoDataFrame, read_file
from shapely.geometry import Point, LineString, Polygon
from datetime import datetime, timedelta

# %% [markdown]
# ## Creating a trajectory from scratch
#
# Trajectory objects consist of a trajectory ID and a GeoPandas GeoDataFrame with a DatetimeIndex. The data frame therefore represents the trajectory data as a Pandas time series with associated point locations (and optional further attributes).

# %%
df = pd.DataFrame([
  {'geometry':Point(0,0), 't':datetime(2018,1,1,12,0,0)},
  {'geometry':Point(6,0), 't':datetime(2018,1,1,12,6,0)},
  {'geometry':Point(6,6), 't':datetime(2018,1,1,12,10,0)},
  {'geometry':Point(9,9), 't':datetime(2018,1,1,12,15,0)}
]).set_index('t')
geo_df = GeoDataFrame(df, crs={'init': '31256'})
toy_traj = mp.Trajectory(1, geo_df)
toy_traj.df
# Out:
#                         geometry
# t
# 2018-01-01 12:00:00  POINT (0 0)
# 2018-01-01 12:06:00  POINT (6 0)
# 2018-01-01 12:10:00  POINT (6 6)
# 2018-01-01 12:15:00  POINT (9 9)

# %%
print(toy_traj)
# Out:
# Trajectory 1 (2018-01-01 12:00:00 to 2018-01-01 12:15:00) | Size: 4 | Length: 16.2m
# Bounds: (0.0, 0.0, 9.0, 9.0)
# LINESTRING (0 0, 6 0, 6 6, 9 9)

# %%
toy_traj.df
# Out:
#                         geometry      prev_pt  dist_to_prev
# t
# 2018-01-01 12:00:00  POINT (0 0)          NaN      0.000000
# 2018-01-01 12:06:00  POINT (6 0)  POINT (0 0)      6.000000
# 2018-01-01 12:10:00  POINT (6 6)  POINT (6 0)      6.000000
# 2018-01-01 12:15:00  POINT (9 9)  POINT (6 6)      4.242641

# %% [markdown]
# The notebook environment automatically plots Shapely geometry objects like the LineString returned by to_linestring() or the Point returned by get_position_at():

# %%
toy_traj.to_linestring()

# %%
toy_traj.add_speed()
toy_traj.df
# Out:
#                         geometry      prev_pt  dist_to_prev  delta_t     speed
# t
# 2018-01-01 12:00:00  POINT (0 0)          NaN      0.000000      NaT  0.016667
# 2018-01-01 12:06:00  POINT (6 0)  POINT (0 0)      6.000000 00:06:00  0.016667
# 2018-01-01 12:10:00  POINT (6 6)  POINT (6 0)      6.000000 00:04:00  0.025000
# 2018-01-01 12:15:00  POINT (9 9)  POINT (6 6)      4.242641 00:05:00  0.014142

# %%
toy_traj.plot(column="speed")

# %%
toy_traj.get_position_at(datetime(2018,1,1,12,6,0), method="nearest")

# %%
print(toy_traj.get_position_at(datetime(2018,1,1,12,6,0), method="nearest"))
# Out:
# POINT (6 0)

# %% [markdown]
# ## Extracting trajectory segments based on time or geometry (i.e. clipping)
#
# First, let's extract the trajectory segment for a certain time period:

# %%
print(toy_traj.get_segment_between(datetime(2018,1,1,12,6,0),datetime(2018,1,1,12,12,0)))
# Out:
# Trajectory 1 (2018-01-01 12:06:00 to 2018-01-01 12:10:00) | Size: 2 | Length: 6.0m
# Bounds: (6.0, 0.0, 6.0, 6.0)
# LINESTRING (6 0, 6 6)

# %% [markdown]
# Now, let's extract the trajectory segment that intersects with a given polygon:

# %%
xmin, xmax, ymin, ymax = 2, 8, -10, 5
polygon = Polygon([(xmin, ymin), (xmin, ymax), (xmax, ymax), (xmax, ymin), (xmin, ymin)])
polygon

# %%
intersection = toy_traj.clip(polygon)
print(intersection[0])
# Out:
# Trajectory 1_0 (2018-01-01 12:02:00 to 2018-01-01 12:09:20) | Size: 3 | Length: 9.0m
# Bounds: (2.0, 0.0, 6.0, 5.0)
# LINESTRING (2 0, 6 0, 6 5)

# %%
intersection[0].plot()

# %% [markdown]
# ## Loading trajectory data from GeoPackage
#
# The MovingPandas repository contains a demo GeoPackage file that can be loaded as follows:

# %%
url = 'https://github.com/anitagraser/movingpandas/raw/master/demo/demodata_geolife.gpkg'
filename = url.split('/')[-1] 

response = urllib.request.urlopen(url)
content = response.read()
with open(filename, 'wb' ) as f:
    f.write( content )

# %%
assert(os.path.exists(filename))

# %% [markdown]
# Now, we can use GeoPandas' read_file() function to read the GeoPackage and construct the Trajectories:

# %%
t_start = datetime.now()
df = read_file(filename)
df['t'] = pd.to_datetime(df['t'])
df = df.set_index('t')
print("Finished reading {} rows in {}".format(len(df),datetime.now() - t_start))

t_start = datetime.now()
trajectories = []
for key, values in df.groupby(['trajectory_id']):
    trajectory = mp.Trajectory(key, values)
    print(trajectory)
    trajectories.append(trajectory)
print("Finished creating {} trajectories in {}".format(len(trajectories),datetime.now() - t_start))
# Out:
# Finished reading 5908 rows in 0:00:00.354996
# Trajectory 1 (2008-12-11 04:42:14+00:00 to 2008-12-11 05:15:46+00:00) | Size: 466 | Length: 6210.1m
# Bounds: (116.385602, 39.862378, 116.393553, 39.898723)
# LINESTRING (116.391305 39.898573, 116.391317 39.898617, 116.390928 39.898613, 116.390833 39.898635,
# Trajectory 2 (2009-06-29 07:02:25+00:00 to 2009-06-29 11:13:12+00:00) | Size: 897 | Length: 38728.7m
# Bounds: (116.319212, 39.971703, 116.592616, 40.082514)
# LINESTRING (116.590957 40.071961, 116.590905 40.072007, 116.590879 40.072027, 116.590915 40.072004,
# Trajectory 3 (2009-02-04 04:32:53+00:00 to 2009-02-04 11:20:12+00:00) | Size: 1810 | Length: 12739.2m
# Bounds: (116.332706, 39.897023, 116.387307, 39.927949)
# LINESTRING (116.385689 39.899773, 116.385654 39.899651, 116.385548 39.899699, 116.385527 39.899632,
# Trajectory 4 (2009-03-10 10:36:45+00:00 to 2009-03-10 12:01:07+00:00) | Size: 1864 | Length: 14357.6m
# Bounds: (116.327347, 39.896671, 116.389611, 39.927947)
# LINESTRING (116.388053 39.903418, 116.388042 39.9035, 116.388035 39.903467, 116.388061 39.903541, 11
# Trajectory 5 (2009-02-25 09:47:03+00:00 to 2009-02-25 14:31:24+00:00) | Size: 871 | Length: 39289.3m
# Bounds: (116.294527, 39.89825, 116.38552, 40.052399)
# LINESTRING (116.385256 39.90027, 116.38525 39.900222, 116.385374 39.900249, 116.385368 39.900264, 11
# Finished creating 5 trajectories in 0:00:01.404677

# %% [markdown]
# Let's look at one of those trajectories:

# %%
trajectories[1].plot(column='speed')

# %%
trajectories[1].plot(with_basemap=True, linewidth=3.0, figsize=(9,9))

# %% [markdown]
# ## Finding intersections with a Shapely polygon

# %%
xmin, xmax, ymin, ymax = 116.3685035,116.3702945,39.904675,39.907728
polygon = Polygon([(xmin,ymin), (xmin,ymax), (xmax,ymax), (xmax,ymin), (xmin,ymin)])

intersections = []
for key, values in df.groupby(['trajectory_id']):
    traj = mp.Trajectory(key, values)
    for intersection in traj.clip(polygon):
        intersections.append(intersection)
print("Found {} intersections".format(len(intersections)))
# Out:
# C:\Users\anita\Documents\GitHub\anitagraser\movingpandas\movingpandas\trajectory.py:78: UserWarning: Discarding nonzero nanoseconds in conversion
#   if not self.get_start_time() < self.get_end_time():
# Found 3 intersections
# C:\Users\anita\Documents\GitHub\anitagraser\movingpandas\movingpandas\trajectory.py:78: UserWarning: Discarding nonzero nanoseconds in conversion
#   if not self.get_start_time() < self.get_end_time():
# C:\Users\anita\Documents\GitHub\anitagraser\movingpandas\movingpandas\trajectory.py:78: UserWarning: Discarding nonzero nanoseconds in conversion
#   if not self.get_start_time() < self.get_end_time():

# %%
intersections[2].plot()

# %% [markdown]
# ## Splitting trajectories
#
# Gaps are quite common in trajectories. For example, GPS tracks may contain gaps if moving objects enter tunnels where GPS reception is lost. In other use cases, moving objects may leave the observation area for longer time before returning and continuing their recorded track.
#
# Depending on the use case, we therefore might want to split trajectories at observation gaps that exceed a certain minimum duration:

# %%
print(trajectories[1])
# Out:
# Trajectory 2 (2009-06-29 07:02:25+00:00 to 2009-06-29 11:13:12+00:00) | Size: 897 | Length: 38728.7m
# Bounds: (116.319212, 39.971703, 116.592616, 40.082514)
# LINESTRING (116.590957 40.071961, 116.590905 40.072007, 116.590879 40.072027, 116.590915 40.072004,

# %%
split = trajectories[1].split_by_observation_gap(timedelta(minutes=5))
for traj in split:
    print(traj)
# Out:
# Trajectory 2_0 (2009-06-29 07:02:25+00:00 to 2009-06-29 07:17:05+00:00) | Size: 152 | Length: 2554.1m
# Bounds: (116.586342, 40.07196, 116.592616, 40.082514)
# LINESTRING (116.590957 40.071961, 116.590905 40.072007, 116.590879 40.072027, 116.590915 40.072004,
# Trajectory 2_1 (2009-06-29 07:29:35+00:00 to 2009-06-29 08:20:15+00:00) | Size: 619 | Length: 33733.3m
# Bounds: (116.319212, 39.971703, 116.587085, 40.079854)
# LINESTRING (116.587031 40.07951, 116.587041 40.079514, 116.587032 40.079524, 116.586998 40.079528, 1
# Trajectory 2_2 (2009-06-29 10:57:17+00:00 to 2009-06-29 11:13:12+00:00) | Size: 126 | Length: 2326.4m
# Bounds: (116.319598, 39.999772, 116.327485, 40.007696)
# LINESTRING (116.319697 40.007513, 116.319706 40.007586, 116.319636 40.007687, 116.319598 40.007696,

# %%
split[0].plot()

# %% [markdown]
# ## Generalizing trajectories
#
# To reduce the size of trajectory objects, we can generalize them, for example, using the Douglas-Peucker algorithm:

# %%
trajectories[1].plot(column='speed')

# %% [markdown]
# Try different tolerance settings and observe the results in line geometry and therefore also length:

# %%
generalized_traj = trajectories[1].generalize(mode='douglas-peucker', tolerance=0.001)
generalized_traj.plot(column='speed')

# %%
print('Original length: %s'%(trajectories[1].get_length()))
print('Generalized length: %s'%(generalized_traj.get_length()))
# Out:
# Original length: 38728.7215399247
# Generalized length: 36295.61630501229

# %%
generalized_traj.df
# Out:
#                              id  sequence  trajectory_id  tracker  \
# t
# 2009-06-29 07:02:25+00:00  1556      1090              2        0
# 2009-06-29 07:05:00+00:00  1590      1124              2        0
# 2009-06-29 07:07:20+00:00  1622      1156              2        0
# 2009-06-29 07:08:30+00:00  1636      1170              2        0
# 2009-06-29 07:09:35+00:00  1649      1183              2        0
# 2009-06-29 07:11:55+00:00  1678      1212              2        0
# 2009-06-29 07:13:55+00:00  1704      1238              2        0
# 2009-06-29 07:33:25+00:00  1755      1289              2        0
# 2009-06-29 07:34:20+00:00  1766      1300              2        0
# 2009-06-29 07:36:00+00:00  1786      1320              2        0
# 2009-06-29 07:38:25+00:00  1815      1349              2        0
# 2009-06-29 07:42:20+00:00  1862      1396              2        0
# 2009-06-29 07:47:10+00:00  1920      1454              2        0
# 2009-06-29 07:50:10+00:00  1956      1490              2        0
# 2009-06-29 08:07:20+00:00  2172      1706              2        0
# 2009-06-29 08:09:00+00:00  2192      1726              2        0
# 2009-06-29 08:11:30+00:00  2222      1756              2        0
# 2009-06-29 08:13:05+00:00  2241      1775              2        0
# 2009-06-29 08:18:40+00:00  2308      1842              2        0
# 2009-06-29 10:59:32+00:00  2354      1888              2        0
# 2009-06-29 11:02:52+00:00  2394      1928              2        0
# 2009-06-29 11:06:52+00:00  2446      1980              2        0
# 2009-06-29 11:09:47+00:00  2448      1982              2        0
# 2009-06-29 11:13:12+00:00  2452      1986              2        0
#
#                                                geometry  \
# t
# 2009-06-29 07:02:25+00:00  POINT (116.590957 40.071961)
# 2009-06-29 07:05:00+00:00  POINT (116.591372 40.074108)
# 2009-06-29 07:07:20+00:00  POINT (116.592394 40.075638)
# 2009-06-29 07:08:30+00:00    POINT (116.5894 40.078235)
# 2009-06-29 07:09:35+00:00  POINT (116.589764 40.081866)
# 2009-06-29 07:11:55+00:00  POINT (116.586551 40.081469)
# 2009-06-29 07:13:55+00:00  POINT (116.588102 40.080607)
# 2009-06-29 07:33:25+00:00  POINT (116.580842 40.078046)
# 2009-06-29 07:34:20+00:00  POINT (116.581864 40.071595)
# 2009-06-29 07:36:00+00:00  POINT (116.583725 40.052388)
# 2009-06-29 07:38:25+00:00  POINT (116.565174 40.034552)
# 2009-06-29 07:42:20+00:00   POINT (116.51158 40.013539)
# 2009-06-29 07:47:10+00:00  POINT (116.463762 39.971775)
# 2009-06-29 07:50:10+00:00  POINT (116.434623 39.987038)
# 2009-06-29 08:07:20+00:00  POINT (116.324009 39.984793)
# 2009-06-29 08:09:00+00:00  POINT (116.326763 39.986232)
# 2009-06-29 08:11:30+00:00    POINT (116.32555 39.99151)
# 2009-06-29 08:13:05+00:00  POINT (116.322136 39.992835)
# 2009-06-29 08:18:40+00:00  POINT (116.320117 40.007747)
# 2009-06-29 10:59:32+00:00  POINT (116.321238 40.005481)
# 2009-06-29 11:02:52+00:00  POINT (116.322876 39.999944)
# 2009-06-29 11:06:52+00:00   POINT (116.327272 40.00048)
# 2009-06-29 11:09:47+00:00  POINT (116.323486 40.000369)
# 2009-06-29 11:13:12+00:00   POINT (116.32746 40.000522)
#
#                                                 prev_pt  dist_to_prev  \
# t
# 2009-06-29 07:02:25+00:00                           NaN      0.000000
# 2009-06-29 07:05:00+00:00  POINT (116.590957 40.071961)    241.332919
# 2009-06-29 07:07:20+00:00  POINT (116.591372 40.074108)    191.063945
# 2009-06-29 07:08:30+00:00  POINT (116.592394 40.075638)    385.075985
# 2009-06-29 07:09:35+00:00    POINT (116.5894 40.078235)    404.934772
# 2009-06-29 07:11:55+00:00  POINT (116.589764 40.081866)    276.898051
# 2009-06-29 07:13:55+00:00  POINT (116.586551 40.081469)    163.095215
# 2009-06-29 07:33:25+00:00  POINT (116.588102 40.080607)    680.172444
# 2009-06-29 07:34:20+00:00  POINT (116.580842 40.078046)    722.570146
# 2009-06-29 07:36:00+00:00  POINT (116.581864 40.071595)   2141.585184
# 2009-06-29 07:38:25+00:00  POINT (116.583725 40.052388)   2535.183690
# 2009-06-29 07:42:20+00:00  POINT (116.565174 40.034552)   5126.922497
# 2009-06-29 07:47:10+00:00   POINT (116.51158 40.013539)   6177.405316
# 2009-06-29 07:50:10+00:00  POINT (116.463762 39.971775)   3007.449804
# 2009-06-29 08:07:20+00:00  POINT (116.434623 39.987038)   9427.377052
# 2009-06-29 08:09:00+00:00  POINT (116.324009 39.984793)    284.002079
# 2009-06-29 08:11:30+00:00  POINT (116.326763 39.986232)    595.915597
# 2009-06-29 08:13:05+00:00    POINT (116.32555 39.99151)    326.028004
# 2009-06-29 08:18:40+00:00  POINT (116.322136 39.992835)   1667.033474
# 2009-06-29 10:59:32+00:00  POINT (116.320117 40.007747)    269.450807
# 2009-06-29 11:02:52+00:00  POINT (116.321238 40.005481)    631.296588
# 2009-06-29 11:06:52+00:00  POINT (116.322876 39.999944)    379.164805
# 2009-06-29 11:09:47+00:00   POINT (116.327272 40.00048)    322.726551
# 2009-06-29 11:13:12+00:00  POINT (116.323486 40.000369)    338.931380
#
#                            delta_t      speed  \
# t
# 2009-06-29 07:02:25+00:00      NaT   1.352640
# 2009-06-29 07:05:00+00:00 00:00:05   2.266064
# 2009-06-29 07:07:20+00:00 00:00:05   8.525305
# 2009-06-29 07:08:30+00:00 00:00:05   6.538815
# 2009-06-29 07:09:35+00:00 00:00:05   6.186321
# 2009-06-29 07:11:55+00:00 00:00:05   6.200769
# 2009-06-29 07:13:55+00:00 00:00:02   0.085080
# 2009-06-29 07:33:25+00:00 00:00:05  11.500023
# 2009-06-29 07:34:20+00:00 00:00:05  19.125717
# 2009-06-29 07:36:00+00:00 00:00:05  21.730611
# 2009-06-29 07:38:25+00:00 00:00:05  23.496364
# 2009-06-29 07:42:20+00:00 00:00:05  23.637122
# 2009-06-29 07:47:10+00:00 00:00:05  15.864693
# 2009-06-29 07:50:10+00:00 00:00:05  21.148532
# 2009-06-29 08:07:20+00:00 00:00:05   3.345801
# 2009-06-29 08:09:00+00:00 00:00:05   3.242956
# 2009-06-29 08:11:30+00:00 00:00:05   5.541869
# 2009-06-29 08:13:05+00:00 00:00:05   4.688800
# 2009-06-29 08:18:40+00:00 00:00:05   4.547587
# 2009-06-29 10:59:32+00:00 00:00:05   1.237103
# 2009-06-29 11:02:52+00:00 00:00:05   2.857110
# 2009-06-29 11:06:52+00:00 00:00:05   0.339868
# 2009-06-29 11:09:47+00:00 00:00:35   7.009900
# 2009-06-29 11:13:12+00:00 00:03:05   0.315369
#
#                                                                         line  \
# t
# 2009-06-29 07:02:25+00:00                                               None
# 2009-06-29 07:05:00+00:00  LINESTRING (116.590957 40.071961, 116.591372 4...
# 2009-06-29 07:07:20+00:00  LINESTRING (116.591372 40.074108, 116.592394 4...
# 2009-06-29 07:08:30+00:00  LINESTRING (116.592394 40.075638, 116.5894 40....
# 2009-06-29 07:09:35+00:00  LINESTRING (116.5894 40.078235, 116.589764 40....
# 2009-06-29 07:11:55+00:00  LINESTRING (116.589764 40.081866, 116.586551 4...
# 2009-06-29 07:13:55+00:00  LINESTRING (116.586551 40.081469, 116.588102 4...
# 2009-06-29 07:33:25+00:00  LINESTRING (116.588102 40.080607, 116.580842 4...
# 2009-06-29 07:34:20+00:00  LINESTRING (116.580842 40.078046, 116.581864 4...
# 2009-06-29 07:36:00+00:00  LINESTRING (116.581864 40.071595, 116.583725 4...
# 2009-06-29 07:38:25+00:00  LINESTRING (116.583725 40.052388, 116.565174 4...
# 2009-06-29 07:42:20+00:00  LINESTRING (116.565174 40.034552, 116.51158 40...
# 2009-06-29 07:47:10+00:00  LINESTRING (116.51158 40.013539, 116.463762 39...
# 2009-06-29 07:50:10+00:00  LINESTRING (116.463762 39.971775, 116.434623 3...
# 2009-06-29 08:07:20+00:00  LINESTRING (116.434623 39.987038, 116.324009 3...
# 2009-06-29 08:09:00+00:00  LINESTRING (116.324009 39.984793, 116.326763 3...
# 2009-06-29 08:11:30+00:00  LINESTRING (116.326763 39.986232, 116.32555 39...
# 2009-06-29 08:13:05+00:00  LINESTRING (116.32555 39.99151, 116.322136 39....
# 2009-06-29 08:18:40+00:00  LINESTRING (116.322136 39.992835, 116.320117 4...
# 2009-06-29 10:59:32+00:00  LINESTRING (116.320117 40.007747, 116.321238 4...
# 2009-06-29 11:02:52+00:00  LINESTRING (116.321238 40.005481, 116.322876 3...
# 2009-06-29 11:06:52+00:00  LINESTRING (116.322876 39.999944, 116.327272 4...
# 2009-06-29 11:09:47+00:00  LINESTRING (116.327272 40.00048, 116.323486 40...
# 2009-06-29 11:13:12+00:00  LINESTRING (116.323486 40.000369, 116.32746 40...
#
#                                                   t  gap
# t
# 2009-06-29 07:02:25+00:00 2009-06-29 07:02:25+00:00    0
# 2009-06-29 07:05:00+00:00 2009-06-29 07:05:00+00:00    0
# 2009-06-29 07:07:20+00:00 2009-06-29 07:07:20+00:00    0
# 2009-06-29 07:08:30+00:00 2009-06-29 07:08:30+00:00    0
# 2009-06-29 07:09:35+00:00 2009-06-29 07:09:35+00:00    0
# 2009-06-29 07:11:55+00:00 2009-06-29 07:11:55+00:00    0
# 2009-06-29 07:13:55+00:00 2009-06-29 07:13:55+00:00    0
# 2009-06-29 07:33:25+00:00 2009-06-29 07:33:25+00:00    1
# 2009-06-29 07:34:20+00:00 2009-06-29 07:34:20+00:00    1
# 2009-06-29 07:36:00+00:00 2009-06-29 07:36:00+00:00    1
# 2009-06-29 07:38:25+00:00 2009-06-29 07:38:25+00:00    1
# 2009-06-29 07:42:20+00:00 2009-06-29 07:42:20+00:00    1
# 2009-06-29 07:47:10+00:00 2009-06-29 07:47:10+00:00    1
# 2009-06-29 07:50:10+00:00 2009-06-29 07:50:10+00:00    1
# 2009-06-29 08:07:20+00:00 2009-06-29 08:07:20+00:00    1
# 2009-06-29 08:09:00+00:00 2009-06-29 08:09:00+00:00    1
# 2009-06-29 08:11:30+00:00 2009-06-29 08:11:30+00:00    1
# 2009-06-29 08:13:05+00:00 2009-06-29 08:13:05+00:00    1
# 2009-06-29 08:18:40+00:00 2009-06-29 08:18:40+00:00    1
# 2009-06-29 10:59:32+00:00 2009-06-29 10:59:32+00:00    2
# 2009-06-29 11:02:52+00:00 2009-06-29 11:02:52+00:00    2
# 2009-06-29 11:06:52+00:00 2009-06-29 11:06:52+00:00    2
# 2009-06-29 11:09:47+00:00 2009-06-29 11:09:47+00:00    2
# 2009-06-29 11:13:12+00:00 2009-06-29 11:13:12+00:00    2
